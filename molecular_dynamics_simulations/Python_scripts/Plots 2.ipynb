# %%
import mdtraj as md
import numpy as np
import matplotlib.pyplot as plt

# Load trajectories
traj_bent_protein = md.load('bent_4_microsecond_c_alpha.xtc', top='bent_4_microsecond_c_alpha_frame0.pdb')
traj_int1_protein = md.load('int1_4_microsecond_c_alpha.xtc', top='int1_4_microsecond_c_alpha_frame0.pdb')

# Crop each trajectory to the required frames
traj_bent_protein = traj_bent_protein[:45000]
traj_int1_protein = traj_int1_protein[:45000]

# Select C-alpha atoms
ca_atoms_bent = traj_bent_protein.topology.select('name CA')
ca_atoms_int1 = traj_int1_protein.topology.select('name CA')

# Extract the trajectory of C-alpha atoms
ca_traj_bent_protein = traj_bent_protein.atom_slice(ca_atoms_bent)
ca_traj_int1_protein = traj_int1_protein.atom_slice(ca_atoms_int1)

# %%
Domain_1_range_bent = ca_traj_bent_protein.topology.select('resid 0 to 451')
Domain_2_range_bent = ca_traj_bent_protein.topology.select('resid 452 to 607')
Domain_3_range_bent = ca_traj_bent_protein.topology.select('resid 608 to 742')
Domain_4_range_bent = ca_traj_bent_protein.topology.select('resid 743 to 963')
Domain_5_range_bent = ca_traj_bent_protein.topology.select('resid 964 to 1007')
Domain_6_range_bent = ca_traj_bent_protein.topology.select('resid 1008 to 1064')
#Domain_7_range = ca_traj_big_protein.topology.select('resid 1065 to 1116' | 'resid 1360 to 1439')
Domain_8_range_bent = ca_traj_bent_protein.topology.select('resid 1117 to 1359')
Domain_9_range_bent = ca_traj_bent_protein.topology.select('resid 1440 to 1482')
Domain_10_range_bent = ca_traj_bent_protein.topology.select('resid 1483 to 1532')
Domain_11_range_bent = ca_traj_bent_protein.topology.select('resid 1533 to 1567')
Domain_12_range_bent = ca_traj_bent_protein.topology.select('resid 1568 to 1611')
Domain_13_range_bent = ca_traj_bent_protein.topology.select('resid 1612 to 1697')
Domain_14_range_bent = ca_traj_bent_protein.topology.select('resid 1698 to 1769')

# %%
Domain_1_traj_bent = ca_traj_bent_protein.atom_slice(Domain_1_range_bent)
Domain_2_traj_bent = ca_traj_bent_protein.atom_slice(Domain_2_range_bent)
Domain_3_traj_bent = ca_traj_bent_protein.atom_slice(Domain_3_range_bent)
Domain_4_traj_bent = ca_traj_bent_protein.atom_slice(Domain_4_range_bent)
Domain_5_traj_bent = ca_traj_bent_protein.atom_slice(Domain_5_range_bent)
Domain_6_traj_bent = ca_traj_bent_protein.atom_slice(Domain_6_range_bent)
#Domain_7_traj = ca_traj_big_protein.atom_slice(Domain_7_range)  # this done separately in next cell 
Domain_8_traj_bent = ca_traj_bent_protein.atom_slice(Domain_8_range_bent)
Domain_9_traj_bent = ca_traj_bent_protein.atom_slice(Domain_9_range_bent)
Domain_10_traj_bent = ca_traj_bent_protein.atom_slice(Domain_10_range_bent)
Domain_11_traj_bent = ca_traj_bent_protein.atom_slice(Domain_11_range_bent)
Domain_12_traj_bent = ca_traj_bent_protein.atom_slice(Domain_12_range_bent)
Domain_13_traj_bent = ca_traj_bent_protein.atom_slice(Domain_13_range_bent)
Domain_14_traj_bent = ca_traj_bent_protein.atom_slice(Domain_14_range_bent)

# %%
# Define the residues of Hybrid Domain ranges as lists
range1 = list(range(1065, 1117))
range2 = list(range(1360, 1440))

# Combine the ranges into a single list
combined_range = range1 + range2

# Convert the list to a NumPy array for slicing
combined_indices = np.array(combined_range)

# Use the combined_indices to slice the trajectory
Domain_7_traj_bent = ca_traj_bent_protein.atom_slice(combined_indices)

# %%
# testing..
# Get the number of residues
n_residues = Domain_7_traj_bent.topology.n_residues

# Print the result
print("Number of Residues:", n_residues)  #should show 132
# Out:
# Number of Residues: 132

# %%
Domain_1_bent_protein_rmsd = md.rmsd( Domain_1_traj_bent, Domain_1_traj_bent, 0)
Domain_2_bent_protein_rmsd = md.rmsd( Domain_2_traj_bent, Domain_2_traj_bent, 0)
Domain_3_bent_protein_rmsd = md.rmsd( Domain_3_traj_bent, Domain_3_traj_bent, 0)
Domain_4_bent_protein_rmsd = md.rmsd( Domain_4_traj_bent, Domain_4_traj_bent, 0)
Domain_5_bent_protein_rmsd = md.rmsd( Domain_5_traj_bent, Domain_5_traj_bent, 0)
Domain_6_bent_protein_rmsd = md.rmsd( Domain_6_traj_bent, Domain_6_traj_bent, 0)
Domain_7_bent_protein_rmsd = md.rmsd( Domain_7_traj_bent, Domain_7_traj_bent, 0)  
Domain_8_bent_protein_rmsd = md.rmsd( Domain_8_traj_bent, Domain_8_traj_bent, 0)
Domain_9_bent_protein_rmsd = md.rmsd( Domain_9_traj_bent, Domain_9_traj_bent, 0)
Domain_10_bent_protein_rmsd = md.rmsd( Domain_10_traj_bent, Domain_10_traj_bent, 0)
Domain_11_bent_protein_rmsd = md.rmsd( Domain_11_traj_bent, Domain_11_traj_bent, 0)
Domain_12_bent_protein_rmsd = md.rmsd( Domain_12_traj_bent, Domain_12_traj_bent, 0)
Domain_13_bent_protein_rmsd = md.rmsd( Domain_13_traj_bent, Domain_13_traj_bent, 0)
Domain_14_bent_protein_rmsd = md.rmsd( Domain_14_traj_bent, Domain_14_traj_bent, 0)

# %%
Domain_1_range_int1 = ca_traj_int1_protein.topology.select('resid 0 to 451')
Domain_2_range_int1 = ca_traj_int1_protein.topology.select('resid 452 to 607')
Domain_3_range_int1 = ca_traj_int1_protein.topology.select('resid 608 to 742')
Domain_4_range_int1 = ca_traj_int1_protein.topology.select('resid 743 to 963')
Domain_5_range_int1 = ca_traj_int1_protein.topology.select('resid 964 to 1007')
Domain_6_range_int1 = ca_traj_int1_protein.topology.select('resid 1008 to 1064')
#Domain_7_range = ca_traj_big_protein.topology.select('resid 1065 to 1116' | 'resid 1360 to 1439')
Domain_8_range_int1 = ca_traj_int1_protein.topology.select('resid 1117 to 1359')
Domain_9_range_int1 = ca_traj_int1_protein.topology.select('resid 1440 to 1482')
Domain_10_range_int1 = ca_traj_int1_protein.topology.select('resid 1483 to 1532')
Domain_11_range_int1 = ca_traj_int1_protein.topology.select('resid 1533 to 1567')
Domain_12_range_int1 = ca_traj_int1_protein.topology.select('resid 1568 to 1611')
Domain_13_range_int1 = ca_traj_int1_protein.topology.select('resid 1612 to 1697')
Domain_14_range_int1 = ca_traj_int1_protein.topology.select('resid 1698 to 1769')

# %%
Domain_1_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_1_range_int1)
Domain_2_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_2_range_int1)
Domain_3_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_3_range_int1)
Domain_4_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_4_range_int1)
Domain_5_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_5_range_int1)
Domain_6_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_6_range_int1)
#Domain_7_traj = ca_traj_big_protein.atom_slice(Domain_7_range)  # this done separately in next cell 
Domain_8_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_8_range_int1)
Domain_9_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_9_range_int1)
Domain_10_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_10_range_int1)
Domain_11_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_11_range_int1)
Domain_12_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_12_range_int1)
Domain_13_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_13_range_int1)
Domain_14_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_14_range_int1)

# %%
# Define the residues of Hybrid Domain ranges as lists
range1 = list(range(1065, 1117))
range2 = list(range(1360, 1440))

# Combine the ranges into a single list
combined_range = range1 + range2

# Convert the list to a NumPy array for slicing
combined_indices = np.array(combined_range)

# Use the combined_indices to slice the trajectory
Domain_7_traj_int1 = ca_traj_int1_protein.atom_slice(combined_indices)

# %%
# testing..
# Get the number of residues
n_residues = Domain_7_traj_int1.topology.n_residues

# Print the result
print("Number of Residues:", n_residues)  #should show 132
# Out:
# Number of Residues: 132

# %%
Domain_1_int1_protein_rmsd = md.rmsd( Domain_1_traj_int1, Domain_1_traj_int1, 0)
Domain_2_int1_protein_rmsd = md.rmsd( Domain_2_traj_int1, Domain_2_traj_int1, 0)
Domain_3_int1_protein_rmsd = md.rmsd( Domain_3_traj_int1, Domain_3_traj_int1, 0)
Domain_4_int1_protein_rmsd = md.rmsd( Domain_4_traj_int1, Domain_4_traj_int1, 0)
Domain_5_int1_protein_rmsd = md.rmsd( Domain_5_traj_int1, Domain_5_traj_int1, 0)
Domain_6_int1_protein_rmsd = md.rmsd( Domain_6_traj_int1, Domain_6_traj_int1, 0)
Domain_7_int1_protein_rmsd = md.rmsd( Domain_7_traj_int1, Domain_7_traj_int1, 0)  
Domain_8_int1_protein_rmsd = md.rmsd( Domain_8_traj_int1, Domain_8_traj_int1, 0)
Domain_9_int1_protein_rmsd = md.rmsd( Domain_9_traj_int1, Domain_9_traj_int1, 0)
Domain_10_int1_protein_rmsd = md.rmsd( Domain_10_traj_int1, Domain_10_traj_int1, 0)
Domain_11_int1_protein_rmsd = md.rmsd( Domain_11_traj_int1, Domain_11_traj_int1, 0)
Domain_12_int1_protein_rmsd = md.rmsd( Domain_12_traj_int1, Domain_12_traj_int1, 0)
Domain_13_int1_protein_rmsd = md.rmsd( Domain_13_traj_int1, Domain_13_traj_int1, 0)
Domain_14_int1_protein_rmsd = md.rmsd( Domain_14_traj_int1, Domain_14_traj_int1, 0)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_1_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_1_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_1_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_1_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('β-Propeller', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Beta_Propeller_RMSD.png', bbox_inches='tight', dpi=350, metadata={'Title': 'β-Propeller RMSD'})

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_2_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_2_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_2_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_2_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Thigh', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Thigh_RMSD.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_3_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_3_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_3_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_3_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Calf-1', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Calf_1_RMSD.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_4_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_4_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_4_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_4_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Calf-2', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Calf_2_RMSD.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_6_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_6_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_6_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_6_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Psi', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Psi_RMSD.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_7_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_7_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_7_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_7_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Hybrid', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Hybrid_RMSD.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_8_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_8_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_8_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_8_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('β-I', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Beta_I_RMSD.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_9_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_9_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_9_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_9_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-1', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22, loc='upper right')

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('E1_RMSD.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_10_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_10_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_10_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_10_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-2', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('E2_RMSD.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_11_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_11_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_11_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_11_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-3', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('E3_RMSD.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_12_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_12_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_12_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_12_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-4', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('E4_RMSD.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define time in microseconds 
time_microseconds = np.arange(0, len(Domain_13_bent_protein_rmsd), dtype=float) * (1e-4)  

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_13_bent_protein_rmsd, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_13_int1_protein_rmsd, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_13_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('β-TD', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSD (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Beta_T_RMSD.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
# List of domains to exclude
exclude_domains = [5, 14]

# Create empty lists to store mean RMSD values for Bent and Int1 trajectories
mean_rmsd_bent = []
mean_rmsd_int1 = []

# Calculate mean RMSD for each domain
for i in range(1, 15):
    if i not in exclude_domains:
        mean_rmsd_bent.append(np.mean(globals()['Domain_' + str(i) + '_bent_protein_rmsd']))
        mean_rmsd_int1.append(np.mean(globals()['Domain_' + str(i) + '_int1_protein_rmsd']))

# Create time array in microseconds (assuming 1 ps timestep)
domains = [1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 12, 13]

# Domain labels
domain_labels = ['β-Prop.', 'Thigh', 'Calf-1', 'Calf-2', 'Psi', 'Hybrid', 'β-I', 'EGF-1', 'EGF-2', 'EGF-3', 'EGF-4', 'β-TD']

# Create a bar plot
width = 0.25  # Width of the bars
fig, ax = plt.subplots(figsize=(25, 8))
rects1 = ax.bar(np.array(domains) - width, mean_rmsd_bent, width, label='Bent', color='black')
rects2 = ax.bar(np.array(domains) , mean_rmsd_int1, width, label='Intermediate', color='blue')
rects3 = ax.bar(np.array(domains) + width, [0.19585715,0.3961668,0.2811971,0.69884807,0.6210293, 0.29938775, 0.36990103,0.98992336, 1.1715026, 0.9202, 0.8458215, 0.4322109], width, label='Isolated', color='red')

# Customize plot appearance
#ax.set_title('Mean RMSD for Bent and Intermediate Trajectories', fontsize=24)
#ax.set_xlabel('Domains', fontsize=80)
ax.set_ylabel('<RMSD> (nm)', fontsize=70)
ax.tick_params(axis='y', labelsize=50)
ax.set_xticks(domains)
ax.set_xticklabels(domain_labels, rotation=45, ha='right', fontsize=58)  # Rotate x-axis labels for better visibility
#ax.legend(fontsize=50, loc='upper left')

plt.savefig('RMSD_Mean_bar_plot.png', bbox_inches='tight', dpi=350)
ax.set_ylim(0, 1.25)

# Show the plot
plt.show()

# %%
# plot 2.B and 2.D
# use only above 2 us for int1 and 
# for bent use same
# check boundaries for E4 and E2
# maintain consistency with Mean RMSF plot

# %%
# Calculation for Error Bars for the RMSD plot

#Error Bars for Bent Domains
# Calculate standard deviation for each variable
beta_propeller_std_1 = np.std(Domain_1_bent_protein_rmsd)
thigh_std_1 = np.std(Domain_2_bent_protein_rmsd)
calf_1_std_1 = np.std(Domain_3_bent_protein_rmsd)
calf_2_std_1 = np.std(Domain_4_bent_protein_rmsd)
psi_std_1 = np.std(Domain_6_bent_protein_rmsd)
hybrid_std_1 = np.std(Domain_7_bent_protein_rmsd)
Beta_I_std_1 = np.std(Domain_8_bent_protein_rmsd)
E1_std_1 = np.std(Domain_9_bent_protein_rmsd)
E2_std_1 = np.std(Domain_10_bent_protein_rmsd)
E3_std_1 = np.std(Domain_11_bent_protein_rmsd)
E4_std_1 = np.std(Domain_12_bent_protein_rmsd)
beta_T_std_1 = np.std(Domain_13_bent_protein_rmsd)

#Error Bars for Int1 Domains
# Calculate standard deviation for each variable
beta_propeller_std_2 = np.std(Domain_1_int1_protein_rmsd)
thigh_std_2 = np.std(Domain_2_int1_protein_rmsd)
calf_1_std_2 = np.std(Domain_3_int1_protein_rmsd)
calf_2_std_2 = np.std(Domain_4_int1_protein_rmsd)
psi_std_2 = np.std(Domain_6_int1_protein_rmsd)
hybrid_std_2 = np.std(Domain_7_int1_protein_rmsd)
Beta_I_std_2 = np.std(Domain_8_int1_protein_rmsd)
E1_std_2 = np.std(Domain_9_int1_protein_rmsd)
E2_std_2 = np.std(Domain_10_int1_protein_rmsd)
E3_std_2 = np.std(Domain_11_int1_protein_rmsd)
E4_std_2 = np.std(Domain_12_int1_protein_rmsd)
beta_T_std_2 = np.std(Domain_13_int1_protein_rmsd)

# Error bars for Isolated Domains
# First let us import the data 
beta_propeller_average_rmsd = np.loadtxt('isolated_beta_propeller_average_rmsf.txt')
thigh_average_rmsd = np.loadtxt('isolated_thigh_average_rmsf.txt')
calf_1_average_rmsd = np.loadtxt('isolated_calf_1_average_rmsf.txt')
calf_2_average_rmsd = np.loadtxt('isolated_Calf_2_average_rmsf.txt')
psi_average_rmsd = np.loadtxt('isolated_psi_average_rmsf.txt')
hybrid_average_rmsd = np.loadtxt('isolated_hybrid_average_rmsf.txt')
Beta_I_average_rmsd = np.loadtxt('isolated_beta_I_average_rmsf.txt')
E1_average_rmsd = np.loadtxt('isolated_E1_average_rmsf.txt')
E2_average_rmsd = np.loadtxt('isolated_E2_average_rmsf.txt')
E3_average_rmsd = np.loadtxt('isolated_E3_average_rmsf.txt')
E4_average_rmsd = np.loadtxt('isolated_E4_average_rmsf.txt')
beta_T_average_rmsd = np.loadtxt('isolated_beta_T_average_rmsf.txt')

# Calculate standard deviation for each variable
beta_propeller_std_3 = np.std(beta_propeller_average_rmsd)
thigh_std_3 = np.std(thigh_average_rmsd)
calf_1_std_3 = np.std(calf_1_average_rmsd)
calf_2_std_3 = np.std(calf_2_average_rmsd)
psi_std_3 = np.std(psi_average_rmsd)
hybrid_std_3 = np.std(hybrid_average_rmsd)
beta_I_std_3 = np.std(Beta_I_average_rmsd)
E1_std_3 = np.std(E1_average_rmsd)
E2_std_3 = np.std(E2_average_rmsd)
E3_std_3 = np.std(E3_average_rmsd)
E4_std_3 = np.std(E4_average_rmsd)
beta_T_std_3 = np.std(beta_T_average_rmsd)

# calculate mean for the imported data, which is height of the bar plot for isolated domains
beta_propeller_mean_3 = (beta_propeller_average_rmsd)
thigh_mean_3 = (thigh_average_rmsd)
calf_1_mean_3 = np.mean(calf_1_average_rmsd)
calf_2_mean_3 = np.mean(calf_2_average_rmsd)
psi_mean_3 = np.mean(psi_average_rmsd)
hybrid_mean_3 = np.mean(hybrid_average_rmsd)
beta_I_mean_3 = np.mean(Beta_I_average_rmsd)
E1_mean_3 = np.mean(E1_average_rmsd)
E2_mean_3 = np.mean(E2_average_rmsd)
E3_mean_3 = np.mean(E3_average_rmsd)
E4_mean_3 = np.mean(E4_average_rmsd)
beta_T_mean_3 = np.mean(beta_T_average_rmsd)

# %%
print(beta_propeller_std_1)

# %%
# standard deviation for 12 isolated domains
0.19585715,
0.3961668,
0.2811971,
0.69884807,
0.6210293, 
0.29938775, 
0.36990103,
0.98992336, 
1.1715026, 
0.9202, 
0.8458215, 
0.4322109

# %%
print(beta_propeller_std_1)
print(thigh_std_1)
print(calf_1_std_1)
print(calf_2_std_1)
print(psi_std_1)
print(hybrid_std_1)
print(Beta_I_std_1)
print(E1_std_1)
print(E2_std_1)
print(E3_std_1)
print(E4_std_1)
print(beta_T_std_1)

# %%
print(beta_propeller_std_2)
print(thigh_std_2)
print(calf_1_std_2)
print(calf_2_std_2)
print(psi_std_2)
print(hybrid_std_2)
print(Beta_I_std_2)
print(E1_std_2)
print(E2_std_2)
print(E3_std_2)
print(E4_std_2)
print(beta_T_std_2)

# %%
# Save Variables
np.savetxt('Domain_1_bent_protein_rmsd.txt', Domain_1_bent_protein_rmsd)
np.savetxt('Domain_2_bent_protein_rmsd.txt', Domain_2_bent_protein_rmsd)
np.savetxt('Domain_3_bent_protein_rmsd.txt', Domain_3_bent_protein_rmsd)
np.savetxt('Domain_4_bent_protein_rmsd.txt', Domain_4_bent_protein_rmsd)
np.savetxt('Domain_5_bent_protein_rmsd.txt', Domain_6_bent_protein_rmsd)
np.savetxt('Domain_6_bent_protein_rmsd.txt', Domain_7_bent_protein_rmsd)
np.savetxt('Domain_7_bent_protein_rmsd.txt', Domain_8_bent_protein_rmsd)
np.savetxt('Domain_8_bent_protein_rmsd.txt', Domain_9_bent_protein_rmsd)
np.savetxt('Domain_9_bent_protein_rmsd.txt', Domain_10_bent_protein_rmsd)
np.savetxt('Domain_10_bent_protein_rmsd.txt', Domain_11_bent_protein_rmsd)
np.savetxt('Domain_11_bent_protein_rmsd.txt', Domain_12_bent_protein_rmsd)
np.savetxt('Domain_12_bent_protein_rmsd.txt', Domain_13_bent_protein_rmsd)

# %%
#save Variables
np.savetxt('Domain_1_int1_protein_rmsd.txt', Domain_1_int1_protein_rmsd)
np.savetxt('Domain_2_int1_protein_rmsd.txt', Domain_2_int1_protein_rmsd)
np.savetxt('Domain_3_int1_protein_rmsd.txt', Domain_3_int1_protein_rmsd)
np.savetxt('Domain_4_int1_protein_rmsd.txt', Domain_4_int1_protein_rmsd)
np.savetxt('Domain_5_int1_protein_rmsd.txt', Domain_6_int1_protein_rmsd)
np.savetxt('Domain_6_int1_protein_rmsd.txt', Domain_7_int1_protein_rmsd)
np.savetxt('Domain_7_int1_protein_rmsd.txt', Domain_8_int1_protein_rmsd)
np.savetxt('Domain_8_int1_protein_rmsd.txt', Domain_9_int1_protein_rmsd)
np.savetxt('Domain_9_int1_protein_rmsd.txt', Domain_10_int1_protein_rmsd)
np.savetxt('Domain_10_int1_protein_rmsd.txt', Domain_11_int1_protein_rmsd)
np.savetxt('Domain_11_int1_protein_rmsd.txt', Domain_12_int1_protein_rmsd)
np.savetxt('Domain_12_int1_protein_rmsd.txt', Domain_13_int1_protein_rmsd)

# %%
print(np.mean(Domain_1_bent_protein_rmsd))
print(np.mean(Domain_2_bent_protein_rmsd))
print(np.mean(Domain_3_bent_protein_rmsd))
print(np.mean(Domain_4_bent_protein_rmsd))
print(np.mean(Domain_5_bent_protein_rmsd))
print(np.mean(Domain_6_bent_protein_rmsd))
print(np.mean(Domain_7_bent_protein_rmsd))
print(np.mean(Domain_8_bent_protein_rmsd))
print(np.mean(Domain_9_bent_protein_rmsd))
print(np.mean(Domain_10_bent_protein_rmsd))
print(np.mean(Domain_11_bent_protein_rmsd))
print(np.mean(Domain_12_bent_protein_rmsd))

# %%
print(np.mean(Domain_1_int1_protein_rmsd))
print(np.mean(Domain_2_int1_protein_rmsd))
print(np.mean(Domain_3_int1_protein_rmsd))
print(np.mean(Domain_4_int1_protein_rmsd))
print(np.mean(Domain_5_int1_protein_rmsd))
print(np.mean(Domain_6_int1_protein_rmsd))
print(np.mean(Domain_7_int1_protein_rmsd))
print(np.mean(Domain_8_int1_protein_rmsd))
print(np.mean(Domain_9_int1_protein_rmsd))
print(np.mean(Domain_10_int1_protein_rmsd))
print(np.mean(Domain_11_int1_protein_rmsd))
print(np.mean(Domain_12_int1_protein_rmsd))

# %%
print(Domain_1_bent_protein_rmsd.size)
