# %%
import mdtraj as md
import numpy as np
import matplotlib.pyplot as plt

# Load trajectories
traj_bent_protein = md.load('bent_4_microsecond_c_alpha.xtc', top='bent_4_microsecond_c_alpha_frame0.pdb')
traj_int1_protein = md.load('int1_4_microsecond_c_alpha.xtc', top='int1_4_microsecond_c_alpha_frame0.pdb')

# Crop each trajectory to the required frames
traj_bent_protein = traj_bent_protein[20000:45000]
traj_int1_protein = traj_int1_protein[20000:45000]

# Select C-alpha atoms
ca_atoms_bent = traj_bent_protein.topology.select('name CA')
ca_atoms_int1 = traj_int1_protein.topology.select('name CA')

# Extract the trajectory of C-alpha atoms
ca_traj_bent_protein = traj_bent_protein.atom_slice(ca_atoms_bent)
ca_traj_int1_protein = traj_int1_protein.atom_slice(ca_atoms_int1)

# %%
Domain_1_range_bent = ca_traj_bent_protein.topology.select('resid 0 to 451')
Domain_2_range_bent = ca_traj_bent_protein.topology.select('resid 452 to 607')
Domain_3_range_bent = ca_traj_bent_protein.topology.select('resid 608 to 742')
Domain_4_range_bent = ca_traj_bent_protein.topology.select('resid 743 to 963')
Domain_5_range_bent = ca_traj_bent_protein.topology.select('resid 964 to 1007')
Domain_6_range_bent = ca_traj_bent_protein.topology.select('resid 1008 to 1064')
#Domain_7_range = ca_traj_big_protein.topology.select('resid 1065 to 1116' | 'resid 1360 to 1439')
Domain_8_range_bent = ca_traj_bent_protein.topology.select('resid 1117 to 1359')
Domain_9_range_bent = ca_traj_bent_protein.topology.select('resid 1440 to 1482')
Domain_10_range_bent = ca_traj_bent_protein.topology.select('resid 1483 to 1532')
Domain_11_range_bent = ca_traj_bent_protein.topology.select('resid 1533 to 1567')
Domain_12_range_bent = ca_traj_bent_protein.topology.select('resid 1568 to 1611')
Domain_13_range_bent = ca_traj_bent_protein.topology.select('resid 1612 to 1697')
Domain_14_range_bent = ca_traj_bent_protein.topology.select('resid 1698 to 1769')

# %%
Domain_1_traj_bent = ca_traj_bent_protein.atom_slice(Domain_1_range_bent)
Domain_2_traj_bent = ca_traj_bent_protein.atom_slice(Domain_2_range_bent)
Domain_3_traj_bent = ca_traj_bent_protein.atom_slice(Domain_3_range_bent)
Domain_4_traj_bent = ca_traj_bent_protein.atom_slice(Domain_4_range_bent)
Domain_5_traj_bent = ca_traj_bent_protein.atom_slice(Domain_5_range_bent)
Domain_6_traj_bent = ca_traj_bent_protein.atom_slice(Domain_6_range_bent)
#Domain_7_traj = ca_traj_big_protein.atom_slice(Domain_7_range)  # this done separately in next cell 
Domain_8_traj_bent = ca_traj_bent_protein.atom_slice(Domain_8_range_bent)
Domain_9_traj_bent = ca_traj_bent_protein.atom_slice(Domain_9_range_bent)
Domain_10_traj_bent = ca_traj_bent_protein.atom_slice(Domain_10_range_bent)
Domain_11_traj_bent = ca_traj_bent_protein.atom_slice(Domain_11_range_bent)
Domain_12_traj_bent = ca_traj_bent_protein.atom_slice(Domain_12_range_bent)
Domain_13_traj_bent = ca_traj_bent_protein.atom_slice(Domain_13_range_bent)
Domain_14_traj_bent = ca_traj_bent_protein.atom_slice(Domain_14_range_bent)

# %%
# Define the residues of Hybrid Domain ranges as lists
range1 = list(range(1065, 1117))
range2 = list(range(1360, 1440))

# Combine the ranges into a single list
combined_range = range1 + range2

# Convert the list to a NumPy array for slicing
combined_indices = np.array(combined_range)

# Use the combined_indices to slice the trajectory
Domain_7_traj_bent = ca_traj_bent_protein.atom_slice(combined_indices)

# %%
# testing..
# Get the number of residues
n_residues = Domain_7_traj_bent.topology.n_residues

# Print the result
print("Number of Residues:", n_residues)  #should show 132
# Out:
# Number of Residues: 132

# %%
Domain_1_bent_protein_rmsf = md.rmsf( Domain_1_traj_bent, Domain_1_traj_bent, 0)
Domain_2_bent_protein_rmsf = md.rmsf( Domain_2_traj_bent, Domain_2_traj_bent, 0)
Domain_3_bent_protein_rmsf = md.rmsf( Domain_3_traj_bent, Domain_3_traj_bent, 0)
Domain_4_bent_protein_rmsf = md.rmsf( Domain_4_traj_bent, Domain_4_traj_bent, 0)
Domain_5_bent_protein_rmsf = md.rmsf( Domain_5_traj_bent, Domain_5_traj_bent, 0)
Domain_6_bent_protein_rmsf = md.rmsf( Domain_6_traj_bent, Domain_6_traj_bent, 0)
Domain_7_bent_protein_rmsf = md.rmsf( Domain_7_traj_bent, Domain_7_traj_bent, 0)  
Domain_8_bent_protein_rmsf = md.rmsf( Domain_8_traj_bent, Domain_8_traj_bent, 0)
Domain_9_bent_protein_rmsf = md.rmsf( Domain_9_traj_bent, Domain_9_traj_bent, 0)
Domain_10_bent_protein_rmsf = md.rmsf( Domain_10_traj_bent, Domain_10_traj_bent, 0)
Domain_11_bent_protein_rmsf = md.rmsf( Domain_11_traj_bent, Domain_11_traj_bent, 0)
Domain_12_bent_protein_rmsf = md.rmsf( Domain_12_traj_bent, Domain_12_traj_bent, 0)
Domain_13_bent_protein_rmsf = md.rmsf( Domain_13_traj_bent, Domain_13_traj_bent, 0)
Domain_14_bent_protein_rmsf = md.rmsf( Domain_14_traj_bent, Domain_14_traj_bent, 0)

# %%
Domain_1_range_int1 = ca_traj_int1_protein.topology.select('resid 0 to 451')
Domain_2_range_int1 = ca_traj_int1_protein.topology.select('resid 452 to 607')
Domain_3_range_int1 = ca_traj_int1_protein.topology.select('resid 608 to 742')
Domain_4_range_int1 = ca_traj_int1_protein.topology.select('resid 743 to 963')
Domain_5_range_int1 = ca_traj_int1_protein.topology.select('resid 964 to 1007')
Domain_6_range_int1 = ca_traj_int1_protein.topology.select('resid 1008 to 1064')
#Domain_7_range = ca_traj_big_protein.topology.select('resid 1065 to 1116' | 'resid 1360 to 1439')
Domain_8_range_int1 = ca_traj_int1_protein.topology.select('resid 1117 to 1359')
Domain_9_range_int1 = ca_traj_int1_protein.topology.select('resid 1440 to 1482')
Domain_10_range_int1 = ca_traj_int1_protein.topology.select('resid 1483 to 1532')
Domain_11_range_int1 = ca_traj_int1_protein.topology.select('resid 1533 to 1567')
Domain_12_range_int1 = ca_traj_int1_protein.topology.select('resid 1568 to 1611')
Domain_13_range_int1 = ca_traj_int1_protein.topology.select('resid 1612 to 1697')
Domain_14_range_int1 = ca_traj_int1_protein.topology.select('resid 1698 to 1769')

# %%
Domain_1_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_1_range_int1)
Domain_2_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_2_range_int1)
Domain_3_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_3_range_int1)
Domain_4_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_4_range_int1)
Domain_5_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_5_range_int1)
Domain_6_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_6_range_int1)
#Domain_7_traj = ca_traj_big_protein.atom_slice(Domain_7_range)  # this done separately in next cell 
Domain_8_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_8_range_int1)
Domain_9_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_9_range_int1)
Domain_10_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_10_range_int1)
Domain_11_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_11_range_int1)
Domain_12_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_12_range_int1)
Domain_13_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_13_range_int1)
Domain_14_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_14_range_int1)

# %%
# Define the residues of Hybrid Domain ranges as lists
range1 = list(range(1065, 1117))
range2 = list(range(1360, 1440))

# Combine the ranges into a single list
combined_range = range1 + range2

# Convert the list to a NumPy array for slicing
combined_indices = np.array(combined_range)

# Use the combined_indices to slice the trajectory
Domain_7_traj_int1 = ca_traj_int1_protein.atom_slice(combined_indices)

# %%
# testing..
# Get the number of residues
n_residues = Domain_7_traj_int1.topology.n_residues

# Print the result
print("Number of Residues:", n_residues)  #should show 132
# Out:
# Number of Residues: 132

# %%
Domain_1_int1_protein_rmsf = md.rmsf( Domain_1_traj_int1, Domain_1_traj_int1, 0)
Domain_2_int1_protein_rmsf = md.rmsf( Domain_2_traj_int1, Domain_2_traj_int1, 0)
Domain_3_int1_protein_rmsf = md.rmsf( Domain_3_traj_int1, Domain_3_traj_int1, 0)
Domain_4_int1_protein_rmsf = md.rmsf( Domain_4_traj_int1, Domain_4_traj_int1, 0)
Domain_5_int1_protein_rmsf = md.rmsf( Domain_5_traj_int1, Domain_5_traj_int1, 0)
Domain_6_int1_protein_rmsf = md.rmsf( Domain_6_traj_int1, Domain_6_traj_int1, 0)
Domain_7_int1_protein_rmsf = md.rmsf( Domain_7_traj_int1, Domain_7_traj_int1, 0)  
Domain_8_int1_protein_rmsf = md.rmsf( Domain_8_traj_int1, Domain_8_traj_int1, 0)
Domain_9_int1_protein_rmsf = md.rmsf( Domain_9_traj_int1, Domain_9_traj_int1, 0)
Domain_10_int1_protein_rmsf = md.rmsf( Domain_10_traj_int1, Domain_10_traj_int1, 0)
Domain_11_int1_protein_rmsf = md.rmsf( Domain_11_traj_int1, Domain_11_traj_int1, 0)
Domain_12_int1_protein_rmsf = md.rmsf( Domain_12_traj_int1, Domain_12_traj_int1, 0)
Domain_13_int1_protein_rmsf = md.rmsf( Domain_13_traj_int1, Domain_13_traj_int1, 0)
Domain_14_int1_protein_rmsf = md.rmsf( Domain_14_traj_int1, Domain_14_traj_int1, 0)

# %%
# Calculation for Error Bars for the rmsf plot

#Error Bars for Bent Domains
# Calculate standard deviation for each variable
beta_propeller_std_1 = np.std(Domain_1_bent_protein_rmsf)
thigh_std_1 = np.std(Domain_2_bent_protein_rmsf)
calf_1_std_1 = np.std(Domain_3_bent_protein_rmsf)
calf_2_std_1 = np.std(Domain_4_bent_protein_rmsf)
psi_std_1 = np.std(Domain_6_bent_protein_rmsf)
hybrid_std_1 = np.std(Domain_7_bent_protein_rmsf)
Beta_I_std_1 = np.std(Domain_8_bent_protein_rmsf)
E1_std_1 = np.std(Domain_9_bent_protein_rmsf)
E2_std_1 = np.std(Domain_10_bent_protein_rmsf)
E3_std_1 = np.std(Domain_11_bent_protein_rmsf)
E4_std_1 = np.std(Domain_12_bent_protein_rmsf)
beta_T_std_1 = np.std(Domain_13_bent_protein_rmsf)

#Error Bars for Int1 Domains
# Calculate standard deviation for each variable
beta_propeller_std_2 = np.std(Domain_1_int1_protein_rmsf)
thigh_std_2 = np.std(Domain_2_int1_protein_rmsf)
calf_1_std_2 = np.std(Domain_3_int1_protein_rmsf)
calf_2_std_2 = np.std(Domain_4_int1_protein_rmsf)
psi_std_2 = np.std(Domain_6_int1_protein_rmsf)
hybrid_std_2 = np.std(Domain_7_int1_protein_rmsf)
Beta_I_std_2 = np.std(Domain_8_int1_protein_rmsf)
E1_std_2 = np.std(Domain_9_int1_protein_rmsf)
E2_std_2 = np.std(Domain_10_int1_protein_rmsf)
E3_std_2 = np.std(Domain_11_int1_protein_rmsf)
E4_std_2 = np.std(Domain_12_int1_protein_rmsf)
beta_T_std_2 = np.std(Domain_13_int1_protein_rmsf)

# %%
isolated_beta_propeller_average_rmsf = np.loadtxt('isolated_beta_propeller_average_rmsf.txt')
isolated_thigh_average_rmsf = np.loadtxt('isolated_thigh_average_rmsf.txt')
isolated_calf_1_average_rmsf = np.loadtxt('isolated_calf_1_average_rmsf.txt')
isolated_calf_2_average_rmsf = np.loadtxt('isolated_Calf_2_average_rmsf.txt')
isolated_psi_average_rmsf = np.loadtxt('isolated_psi_average_rmsf.txt')
isolated_hybrid_average_rmsf = np.loadtxt('isolated_hybrid_average_rmsf.txt')
isolated_beta_I_average_rmsf = np.loadtxt('isolated_beta_I_average_rmsf.txt')
isolated_E1_average_rmsf = np.loadtxt('isolated_E1_average_rmsf.txt')
isolated_E2_average_rmsf = np.loadtxt('isolated_E2_average_rmsf.txt')
isolated_E3_average_rmsf = np.loadtxt('isolated_E3_average_rmsf.txt')
isolated_E4_average_rmsf = np.loadtxt('isolated_E4_average_rmsf.txt')
isolated_beta_T_average_rmsf = np.loadtxt('isolated_beta_T_average_rmsf.txt')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(Domain_1_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(Domain_1_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(isolated_beta_propeller_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('β-Propeller', fontsize=30)
ax.set_xlabel('Residue #', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_1.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Domain_2_range = range(453,609)

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(Domain_2_range, Domain_2_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(Domain_2_range, Domain_2_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(Domain_2_range, isolated_thigh_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Thigh', fontsize=30)
ax.set_xlabel('Residue #', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_2.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Domain_3_range = range(609,744)

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(Domain_3_range, Domain_3_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(Domain_3_range, Domain_3_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(Domain_3_range, isolated_calf_1_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Calf-1', fontsize=30)
ax.set_xlabel('Residue #', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_3.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Domain_4_range = range(744,965)

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(Domain_4_range, Domain_4_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(Domain_4_range, Domain_4_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(Domain_4_range, isolated_calf_2_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Calf-2', fontsize=30)
ax.set_xlabel('Residue #', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_4.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Domain_6_range = range(1009,1066)

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(Domain_6_range, Domain_6_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(Domain_6_range, Domain_6_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(Domain_6_range, isolated_psi_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Psi', fontsize=30)
ax.set_xlabel('Residue #', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_6.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

range1 = list(range(1065, 1117))
range2 = list(range(1360, 1440))

Domain_7_range = combined_range

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(Domain_7_range, Domain_7_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(Domain_7_range, Domain_7_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(Domain_7_range, isolated_hybrid_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Hybrid', fontsize=30)
ax.set_xlabel('Residue #', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_7.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Domain_8_range = range(1118,1361)

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(Domain_8_range, Domain_8_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(Domain_8_range, Domain_8_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(Domain_8_range, isolated_beta_I_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('β-I', fontsize=30)
ax.set_xlabel('Residue #', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22, loc='upper right')

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_8.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Domain_9_range = range(1441,1484)

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(Domain_9_range, Domain_9_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(Domain_9_range, Domain_9_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(Domain_9_range, isolated_E1_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-1', fontsize=30)
ax.set_xlabel('Residue #', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=20, loc='upper right')

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_9.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Domain_10_range = range(1484,1534)

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(Domain_10_range, Domain_10_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(Domain_10_range, Domain_10_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(Domain_10_range, isolated_E2_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-2', fontsize=30)
ax.set_xlabel('Residue #', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))

# Move legend to top right
#ax.legend(frameon=False, fontsize=14, loc='upper right')
# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_10.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Domain_11_range = range(1534,1569)

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(Domain_11_range, Domain_11_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(Domain_11_range, Domain_11_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(Domain_11_range, isolated_E3_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-3', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

ax.tick_params(axis='both', labelsize=26)  # Decrease label size

# Move legend to top right
#ax.legend(frameon=False, fontsize=16, loc='upper right')

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_11.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

Domain_12_range = range(1569,1613)

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(Domain_12_range, Domain_12_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(Domain_12_range, Domain_12_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(Domain_12_range, isolated_E4_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-4', fontsize=30)
ax.set_xlabel('Residue #', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
ax.tick_params(axis='both', labelsize=22)  # Decrease label size

# Move legend to top right
#ax.legend(frameon=False, fontsize=16, loc='upper right')

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_12.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

domain_13_range = range(1613,1699)
# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b','r']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate','Isolated']

# Plot RMSD data for the first domain
ax.plot(domain_13_range, Domain_13_bent_protein_rmsf, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(domain_13_range, Domain_13_int1_protein_rmsf, color=colors[1], linewidth=3.0, label=labels[1])
ax.plot(domain_13_range, isolated_beta_T_average_rmsf, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('β-TD', fontsize=30)
ax.set_xlabel('Residue #', fontsize=30)
ax.set_ylabel('RMSF (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 3, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('RMSF_Plot_13.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
# List of domains to exclude
exclude_domains = [5, 14]

# Create empty lists to store mean RMSD values for Bent and Int1 trajectories
mean_rmsf_bent = []
mean_rmsf_int1 = []

# Calculate mean RMSD for each domain
for i in range(1, 15):
    if i not in exclude_domains:
        mean_rmsf_bent.append(np.mean(globals()['Domain_' + str(i) + '_bent_protein_rmsf']))
        mean_rmsf_int1.append(np.mean(globals()['Domain_' + str(i) + '_int1_protein_rmsf']))

# Create time array in microseconds (assuming 1 ps timestep)
domains = [1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 12, 13]

# Domain labels
domain_labels = ['β-Prop.', 'Thigh', 'Calf-1', 'Calf-2', 'Psi', 'Hybrid', 'β-I', 'EGF-1', 'EGF-2', 'EGF-3', 'EGF-4', 'β-TD']

# Create a bar plot
width = 0.25  # Width of the bars
fig, ax = plt.subplots(figsize=(25, 8))
rects1 = ax.bar(np.array(domains) - width, mean_rmsf_bent, width, label='Bent', color='black')
rects2 = ax.bar(np.array(domains) , mean_rmsf_int1, width, label='Intermediate', color='blue')
rects3 = ax.bar(np.array(domains) + width, [0.09961464,0.20138355,0.14887778, 0.27619594, 0.35278627, 0.16513133, 0.17082831, 0.7901437, 0.9161503, 0.7096599, 0.69881904, 0.24411654], width, label='Isolated', color='red')

# Customize plot appearance
#ax.set_title('Mean RMSF for Bent and Intermediate Trajectories', fontsize=24)
#ax.set_xlabel('Domains', fontsize=80)
ax.set_ylabel('<RMSF> (nm)', fontsize=70)
ax.tick_params(axis='y', labelsize=50)
ax.set_xticks(domains)
ax.set_xticklabels(domain_labels, rotation=45, ha='right', fontsize=58)  # Rotate x-axis labels for better visibility
ax.legend(fontsize=50, loc='upper left')
ax.set_ylim(0, 1.25)

plt.savefig('RMSF_Mean_bar_plot.png', bbox_inches='tight', dpi=350)


# Show the plot
plt.show()

# %%
# thick labels for y-ticks (as big as x-axis)

# %%
# Standard Deviation for the 12 Isolated Domains
0.09961464,
0.20138355,
0.14887778, 
0.27619594, 
0.35278627, 
0.16513133, 
0.17082831, 
0.7901437, 
0.9161503, 
0.7096599, 
0.69881904, 
0.24411654
# Out:
# 0.24411654

# %%
print(beta_propeller_std_1)
print(thigh_std_1)
print(calf_1_std_1)
print(calf_2_std_1)
print(psi_std_1)
print(hybrid_std_1)
print(Beta_I_std_1)
print(E1_std_1)
print(E2_std_1)
print(E3_std_1)
print(E4_std_1)
print(beta_T_std_1)
# Out:
# 0.13844045
# 0.117114134
# 0.07208512
# 0.19463722
# 0.1476813
# 0.058446962
# 0.26338032
# 0.15619938
# 0.115590945
# 0.030272264
# 0.056364033
# 0.21336818

# %%
print(beta_propeller_std_2)
print(thigh_std_2)
print(calf_1_std_2)
print(calf_2_std_2)
print(psi_std_2)
print(hybrid_std_2)
print(Beta_I_std_2)
print(E1_std_2)
print(E2_std_2)
print(E3_std_2)
print(E4_std_2)
print(beta_T_std_2)
# Out:
# 0.1412333
# 0.14544995
# 0.047974158
# 0.22017807
# 0.09698543
# 0.08299959
# 0.14345402
# 0.12642819
# 0.16961102
# 0.114004746
# 0.16545515
# 0.09183916

# %%
# Save Variables
np.savetxt('Domain_1_bent_protein_rmsf.txt', Domain_1_bent_protein_rmsf)
np.savetxt('Domain_2_bent_protein_rmsf.txt', Domain_2_bent_protein_rmsf)
np.savetxt('Domain_3_bent_protein_rmsf.txt', Domain_3_bent_protein_rmsf)
np.savetxt('Domain_4_bent_protein_rmsf.txt', Domain_4_bent_protein_rmsf)
np.savetxt('Domain_5_bent_protein_rmsf.txt', Domain_6_bent_protein_rmsf)
np.savetxt('Domain_6_bent_protein_rmsf.txt', Domain_7_bent_protein_rmsf)
np.savetxt('Domain_7_bent_protein_rmsf.txt', Domain_8_bent_protein_rmsf)
np.savetxt('Domain_8_bent_protein_rmsf.txt', Domain_9_bent_protein_rmsf)
np.savetxt('Domain_9_bent_protein_rmsf.txt', Domain_10_bent_protein_rmsf)
np.savetxt('Domain_10_bent_protein_rmsf.txt', Domain_11_bent_protein_rmsf)
np.savetxt('Domain_11_bent_protein_rmsf.txt', Domain_12_bent_protein_rmsf)
np.savetxt('Domain_12_bent_protein_rmsf.txt', Domain_13_bent_protein_rmsf)

# %%
#save Variables
np.savetxt('Domain_1_int1_protein_rmsf.txt', Domain_1_int1_protein_rmsf)
np.savetxt('Domain_2_int1_protein_rmsf.txt', Domain_2_int1_protein_rmsf)
np.savetxt('Domain_3_int1_protein_rmsf.txt', Domain_3_int1_protein_rmsf)
np.savetxt('Domain_4_int1_protein_rmsf.txt', Domain_4_int1_protein_rmsf)
np.savetxt('Domain_5_int1_protein_rmsf.txt', Domain_6_int1_protein_rmsf)
np.savetxt('Domain_6_int1_protein_rmsf.txt', Domain_7_int1_protein_rmsf)
np.savetxt('Domain_7_int1_protein_rmsf.txt', Domain_8_int1_protein_rmsf)
np.savetxt('Domain_8_int1_protein_rmsf.txt', Domain_9_int1_protein_rmsf)
np.savetxt('Domain_9_int1_protein_rmsf.txt', Domain_10_int1_protein_rmsf)
np.savetxt('Domain_10_int1_protein_rmsf.txt', Domain_11_int1_protein_rmsf)
np.savetxt('Domain_11_int1_protein_rmsf.txt', Domain_12_int1_protein_rmsf)
np.savetxt('Domain_12_int1_protein_rmsf.txt', Domain_13_int1_protein_rmsf)
