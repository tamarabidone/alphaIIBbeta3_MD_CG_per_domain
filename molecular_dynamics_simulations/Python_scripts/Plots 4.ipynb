# %%
import mdtraj as md
import numpy as np
import matplotlib.pyplot as plt

# Load trajectories
traj_bent_protein = md.load('bent_4_microsecond_c_alpha.xtc', top='bent_4_microsecond_c_alpha_frame0.pdb')
traj_int1_protein = md.load('int1_4_microsecond_c_alpha.xtc', top='int1_4_microsecond_c_alpha_frame0.pdb')

# Crop each trajectory to the required frames
traj_bent_protein = traj_bent_protein[:45000]
traj_int1_protein = traj_int1_protein[:45000]

# Select C-alpha atoms
ca_atoms_bent = traj_bent_protein.topology.select('name CA')
ca_atoms_int1 = traj_int1_protein.topology.select('name CA')

# Extract the trajectory of C-alpha atoms
ca_traj_bent_protein = traj_bent_protein.atom_slice(ca_atoms_bent)
ca_traj_int1_protein = traj_int1_protein.atom_slice(ca_atoms_int1)

# %%
Domain_1_range_bent = ca_traj_bent_protein.topology.select('resid 0 to 451')
Domain_2_range_bent = ca_traj_bent_protein.topology.select('resid 452 to 607')
Domain_3_range_bent = ca_traj_bent_protein.topology.select('resid 608 to 742')
Domain_4_range_bent = ca_traj_bent_protein.topology.select('resid 743 to 963')
Domain_5_range_bent = ca_traj_bent_protein.topology.select('resid 964 to 1007')
Domain_6_range_bent = ca_traj_bent_protein.topology.select('resid 1008 to 1064')
#Domain_7_range = ca_traj_big_protein.topology.select('resid 1065 to 1116' | 'resid 1360 to 1439')
Domain_8_range_bent = ca_traj_bent_protein.topology.select('resid 1117 to 1359')
Domain_9_range_bent = ca_traj_bent_protein.topology.select('resid 1440 to 1482')
Domain_10_range_bent = ca_traj_bent_protein.topology.select('resid 1483 to 1532')
Domain_11_range_bent = ca_traj_bent_protein.topology.select('resid 1533 to 1567')
Domain_12_range_bent = ca_traj_bent_protein.topology.select('resid 1568 to 1611')
Domain_13_range_bent = ca_traj_bent_protein.topology.select('resid 1612 to 1697')
Domain_14_range_bent = ca_traj_bent_protein.topology.select('resid 1698 to 1769')

# %%
Domain_1_traj_bent = ca_traj_bent_protein.atom_slice(Domain_1_range_bent)
Domain_2_traj_bent = ca_traj_bent_protein.atom_slice(Domain_2_range_bent)
Domain_3_traj_bent = ca_traj_bent_protein.atom_slice(Domain_3_range_bent)
Domain_4_traj_bent = ca_traj_bent_protein.atom_slice(Domain_4_range_bent)
Domain_5_traj_bent = ca_traj_bent_protein.atom_slice(Domain_5_range_bent)
Domain_6_traj_bent = ca_traj_bent_protein.atom_slice(Domain_6_range_bent)
#Domain_7_traj = ca_traj_big_protein.atom_slice(Domain_7_range)  # this done separately in next cell 
Domain_8_traj_bent = ca_traj_bent_protein.atom_slice(Domain_8_range_bent)
Domain_9_traj_bent = ca_traj_bent_protein.atom_slice(Domain_9_range_bent)
Domain_10_traj_bent = ca_traj_bent_protein.atom_slice(Domain_10_range_bent)
Domain_11_traj_bent = ca_traj_bent_protein.atom_slice(Domain_11_range_bent)
Domain_12_traj_bent = ca_traj_bent_protein.atom_slice(Domain_12_range_bent)
Domain_13_traj_bent = ca_traj_bent_protein.atom_slice(Domain_13_range_bent)
Domain_14_traj_bent = ca_traj_bent_protein.atom_slice(Domain_14_range_bent)

# %%
# Define the residues of Hybrid Domain ranges as lists
range1 = list(range(1065, 1117))
range2 = list(range(1360, 1440))

# Combine the ranges into a single list
combined_range = range1 + range2

# Convert the list to a NumPy array for slicing
combined_indices = np.array(combined_range)

# Use the combined_indices to slice the trajectory
Domain_7_traj_bent = ca_traj_bent_protein.atom_slice(combined_indices)

# %%
# testing..
# Get the number of residues
n_residues = Domain_7_traj_bent.topology.n_residues

# Print the result
print("Number of Residues:", n_residues)  #should show 132
# Out:
# Number of Residues: 132

# %%
Domain_1_bent_protein_rg = md.compute_rg( Domain_1_traj_bent)
Domain_2_bent_protein_rg = md.compute_rg( Domain_2_traj_bent)
Domain_3_bent_protein_rg = md.compute_rg( Domain_3_traj_bent)
Domain_4_bent_protein_rg = md.compute_rg( Domain_4_traj_bent)
Domain_5_bent_protein_rg = md.compute_rg( Domain_5_traj_bent)
Domain_6_bent_protein_rg = md.compute_rg( Domain_6_traj_bent)
Domain_7_bent_protein_rg = md.compute_rg( Domain_7_traj_bent)  
Domain_8_bent_protein_rg = md.compute_rg( Domain_8_traj_bent)
Domain_9_bent_protein_rg = md.compute_rg( Domain_9_traj_bent)
Domain_10_bent_protein_rg = md.compute_rg( Domain_10_traj_bent)
Domain_11_bent_protein_rg = md.compute_rg( Domain_11_traj_bent)
Domain_12_bent_protein_rg = md.compute_rg( Domain_12_traj_bent)
Domain_13_bent_protein_rg = md.compute_rg( Domain_13_traj_bent)
Domain_14_bent_protein_rg = md.compute_rg( Domain_14_traj_bent)

# %%
Domain_1_range_int1 = ca_traj_int1_protein.topology.select('resid 0 to 451')
Domain_2_range_int1 = ca_traj_int1_protein.topology.select('resid 452 to 607')
Domain_3_range_int1 = ca_traj_int1_protein.topology.select('resid 608 to 742')
Domain_4_range_int1 = ca_traj_int1_protein.topology.select('resid 743 to 963')
Domain_5_range_int1 = ca_traj_int1_protein.topology.select('resid 964 to 1007')
Domain_6_range_int1 = ca_traj_int1_protein.topology.select('resid 1008 to 1064')
#Domain_7_range = ca_traj_big_protein.topology.select('resid 1065 to 1116' | 'resid 1360 to 1439')
Domain_8_range_int1 = ca_traj_int1_protein.topology.select('resid 1117 to 1359')
Domain_9_range_int1 = ca_traj_int1_protein.topology.select('resid 1440 to 1482')
Domain_10_range_int1 = ca_traj_int1_protein.topology.select('resid 1483 to 1532')
Domain_11_range_int1 = ca_traj_int1_protein.topology.select('resid 1533 to 1567')
Domain_12_range_int1 = ca_traj_int1_protein.topology.select('resid 1568 to 1611')
Domain_13_range_int1 = ca_traj_int1_protein.topology.select('resid 1612 to 1697')
Domain_14_range_int1 = ca_traj_int1_protein.topology.select('resid 1698 to 1769')

# %%
Domain_1_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_1_range_int1)
Domain_2_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_2_range_int1)
Domain_3_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_3_range_int1)
Domain_4_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_4_range_int1)
Domain_5_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_5_range_int1)
Domain_6_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_6_range_int1)
#Domain_7_traj = ca_traj_big_protein.atom_slice(Domain_7_range)  # this done separately in next cell 
Domain_8_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_8_range_int1)
Domain_9_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_9_range_int1)
Domain_10_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_10_range_int1)
Domain_11_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_11_range_int1)
Domain_12_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_12_range_int1)
Domain_13_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_13_range_int1)
Domain_14_traj_int1 = ca_traj_int1_protein.atom_slice(Domain_14_range_int1)

# %%
# Define the residues of Hybrid Domain ranges as lists
range1 = list(range(1065, 1117))
range2 = list(range(1360, 1440))

# Combine the ranges into a single list
combined_range = range1 + range2

# Convert the list to a NumPy array for slicing
combined_indices = np.array(combined_range)

# Use the combined_indices to slice the trajectory
Domain_7_traj_int1 = ca_traj_int1_protein.atom_slice(combined_indices)

# %%
# testing..
# Get the number of residues
n_residues = Domain_7_traj_int1.topology.n_residues

# Print the result
print("Number of Residues:", n_residues)  #should show 132
# Out:
# Number of Residues: 132

# %%
Domain_1_int1_protein_rg = md.compute_rg( Domain_1_traj_int1)
Domain_2_int1_protein_rg = md.compute_rg( Domain_2_traj_int1)
Domain_3_int1_protein_rg = md.compute_rg( Domain_3_traj_int1)
Domain_4_int1_protein_rg = md.compute_rg( Domain_4_traj_int1)
Domain_5_int1_protein_rg = md.compute_rg( Domain_5_traj_int1)
Domain_6_int1_protein_rg = md.compute_rg( Domain_6_traj_int1)
Domain_7_int1_protein_rg = md.compute_rg( Domain_7_traj_int1)  
Domain_8_int1_protein_rg = md.compute_rg( Domain_8_traj_int1)
Domain_9_int1_protein_rg = md.compute_rg( Domain_9_traj_int1)
Domain_10_int1_protein_rg = md.compute_rg( Domain_10_traj_int1)
Domain_11_int1_protein_rg = md.compute_rg( Domain_11_traj_int1)
Domain_12_int1_protein_rg = md.compute_rg( Domain_12_traj_int1)
Domain_13_int1_protein_rg = md.compute_rg( Domain_13_traj_int1)
Domain_14_int1_protein_rg = md.compute_rg( Domain_14_traj_int1)

# %%
import matplotlib.pyplot as plt
import numpy as np

time_microseconds = np.arange(0, len(Domain_1_bent_protein_rg), dtype=float) * (1e-4)  # Assuming 1 ps timestep

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_1_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_1_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_1_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('β-Propeller', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 4, 1))
ax.legend(frameon=False, fontsize=24, loc='lower right')

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_1.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

time_microseconds = np.arange(0, len(Domain_2_bent_protein_rg), dtype=float) * (1e-4)  # Assuming 1 ps timestep

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_2_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_2_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_2_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Thigh', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 4, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_2.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_3_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_3_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_3_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Calf-1', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 4, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_3.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_4_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_4_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_4_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Calf-2', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=30)
ax.set_yticks(np.arange(0, 4, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_4.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_6_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_6_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_6_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Psi', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 4, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_6.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_7_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_7_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_7_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('Hybrid', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 4, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_7.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_8_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_8_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_8_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('β-I', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 4, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_8.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_9_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_9_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_9_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-1', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 4, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_9.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_10_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_10_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_10_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-2', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 4, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_10.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_11_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_11_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_11_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-3', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 4, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_11.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_12_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_12_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_12_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('EGF-4', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 4, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_12.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a new figure for the first subplot
fig, ax = plt.subplots()

# Define colors and labels
colors = ['k', 'b']  # Bent, Int1, Small protein
labels = ['Bent', 'Intermediate']

# Plot RMSD data for the first domain
ax.plot(time_microseconds, Domain_13_bent_protein_rg, color=colors[0], linewidth=3.0, label=labels[0])
ax.plot(time_microseconds, Domain_13_int1_protein_rg, color=colors[1], linewidth=3.0, label=labels[1])
#ax.plot(time_microseconds, Domain_13_small_protein_rmsd, color=colors[2], linewidth=3.0, label=labels[2])

# Customize subplot appearance
ax.set_title('β-TD', fontsize=30)
ax.set_xlabel('Time (μs)', fontsize=30)
ax.set_ylabel('Rg (nm)', fontsize=30)
ax.tick_params(axis='both', labelsize=26)
ax.set_yticks(np.arange(0, 4, 1))
#ax.legend(frameon=False, fontsize=22)

# Adjust layout to include labels and save the figure
plt.tight_layout()
plt.setp(ax.spines.values(), linewidth=4)

# Save the figure including axis and labels
plt.savefig('Rg_Plot_13.png', bbox_inches='tight', dpi=350)
plt.show()

# %%
# Save Variables
np.savetxt('Domain_1_bent_protein_rg.txt', Domain_1_bent_protein_rg)
np.savetxt('Domain_2_bent_protein_rg.txt', Domain_2_bent_protein_rg)
np.savetxt('Domain_3_bent_protein_rg.txt', Domain_3_bent_protein_rg)
np.savetxt('Domain_4_bent_protein_rg.txt', Domain_4_bent_protein_rg)
np.savetxt('Domain_5_bent_protein_rg.txt', Domain_6_bent_protein_rg)
np.savetxt('Domain_6_bent_protein_rg.txt', Domain_7_bent_protein_rg)
np.savetxt('Domain_7_bent_protein_rg.txt', Domain_8_bent_protein_rg)
np.savetxt('Domain_8_bent_protein_rg.txt', Domain_9_bent_protein_rg)
np.savetxt('Domain_9_bent_protein_rg.txt', Domain_10_bent_protein_rg)
np.savetxt('Domain_10_bent_protein_rg.txt', Domain_11_bent_protein_rg)
np.savetxt('Domain_11_bent_protein_rg.txt', Domain_12_bent_protein_rg)
np.savetxt('Domain_12_bent_protein_rg.txt', Domain_13_bent_protein_rg)

# %%
#save Variables
np.savetxt('Domain_1_int1_protein_rg.txt', Domain_1_int1_protein_rg)
np.savetxt('Domain_2_int1_protein_rg.txt', Domain_2_int1_protein_rg)
np.savetxt('Domain_3_int1_protein_rg.txt', Domain_3_int1_protein_rg)
np.savetxt('Domain_4_int1_protein_rg.txt', Domain_4_int1_protein_rg)
np.savetxt('Domain_5_int1_protein_rg.txt', Domain_6_int1_protein_rg)
np.savetxt('Domain_6_int1_protein_rg.txt', Domain_7_int1_protein_rg)
np.savetxt('Domain_7_int1_protein_rg.txt', Domain_8_int1_protein_rg)
np.savetxt('Domain_8_int1_protein_rg.txt', Domain_9_int1_protein_rg)
np.savetxt('Domain_9_int1_protein_rg.txt', Domain_10_int1_protein_rg)
np.savetxt('Domain_10_int1_protein_rg.txt', Domain_11_int1_protein_rg)
np.savetxt('Domain_11_int1_protein_rg.txt', Domain_12_int1_protein_rg)
np.savetxt('Domain_12_int1_protein_rg.txt', Domain_13_int1_protein_rg)
